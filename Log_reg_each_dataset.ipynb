# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
import os
os.getcwd()
os.chdir('..\data\raw')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\mrafi\\Downloads\\GitRepos\\DSI\\TEAM_PROJECT_1\\data\\raw'

# %%
print( os.listdir(os.getcwd()) )
# Out:
# ['team_project_1']

# %%
# CHANGE THIS LINE TO INCLUDE THE PROPER PATHS
datasets = [pd.read_csv('cardio_train_Kaggle_Svetlana.csv'),pd.read_csv('heart_Kaggle_David_Lapp_Public_Health_Dataset.csv'), pd.read_csv('heart_statlog_IEEE_Dataset.csv')]

# %%
for i, dataset in enumerate(datasets):
   df = datasets[i]
    # Split the dataset into features (X) and target (y)
   X = df.iloc[:, :-1]  # Features are all columns except the last one
   y = df.iloc[:, -1]   # Target is the last column
   
   X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=453)

    # Initialize logistic regression model
   model = LogisticRegression(max_iter=2000)

    # Train the model
   model.fit(X_train, y_train)

    # Evaluate the model
   train_score = model.score(X_train, y_train)
   test_score = model.score(X_test, y_test)

   print(f"  Training set accuracy: {train_score:.2f}")
   print(f"  Testing set accuracy: {test_score:.2f}")
# Out:
# c:\Users\mrafi\miniconda3\envs\dsi_participant\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   Training set accuracy: 0.71
#   Testing set accuracy: 0.71
#   Training set accuracy: 0.86
#   Testing set accuracy: 0.80
#   Training set accuracy: 0.83
#   Testing set accuracy: 0.83
